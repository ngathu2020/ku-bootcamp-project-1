# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crypto_csv = os.path.join("Resources", "consolidated_coin_data.csv")

# %%
consolidated_coin_df = pd.read_csv(crypto_csv)

# %%
consolidated_coin_df
# Out:
#       Currency          Date       Open       High        Low      Close  \
# 0           0x  Dec 27, 2017   0.648181   0.712597   0.617503   0.669701
# 1           0x  Dec 26, 2017   0.693401   0.708796   0.563918   0.647725
# 2           0x  Dec 25, 2017   0.634725   0.717725   0.630453   0.696416
# 3           0x  Dec 24, 2017   0.651100   0.672352   0.534855   0.628460
# 4           0x  Dec 23, 2017   0.502023   0.768043   0.485584   0.645686
# 5           0x  Dec 22, 2017   0.584187   0.587635   0.382546   0.498971
# 6           0x  Dec 21, 2017   0.575139   0.645124   0.521933   0.578530
# 7           0x  Dec 20, 2017   0.562926   0.575164   0.482775   0.575164
# 8           0x  Dec 19, 2017   0.511452   0.589200   0.479695   0.564137
# 9           0x  Dec 18, 2017   0.465889   0.511789   0.423639   0.511789
# 10          0x  Dec 17, 2017   0.384319   0.494670   0.379706   0.463769
# 11          0x  Dec 16, 2017   0.359665   0.394361   0.348884   0.383183
# ...

# %%
#https://data.world/pmohun/complete-historical-cryptocurrency-financial-data/workspace/file?filename=consolidated_coin_data.csv

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
#plt.figure(figsize=(20,3))
#plt.bar(consolidated_coin_df['Currency'], consolidated_coin_df["High"], color='r', alpha=0.5, align="edge")
##plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
#plt.xticks(rotation="vertical")

# %%
consolidated_coin_df["Currency"].value_counts()
# Out:
# namecoin                1705
# bitcoin                 1705
# litecoin                1705
# peercoin                1704
# feathercoin             1700
# ripple                  1607
# nxt                     1485
# dogecoin                1474
# vertcoin                1438
# digibyte                1421
# reddcoin                1416
# dash                    1413
# potcoin                 1411
# counterparty            1410
# blackcoin               1399
# gulden                  1360
# einsteinium             1359
# groestlcoin             1357
# monacoin                1350
# whitecoin               1346
# maidsafecoin            1340
# faircoin                1318
# monero                  1316
# cloakcoin               1300
# nav-coin                1295
# bytecoin-bcn            1290
# digitalnote             1283
# bitcoindark             1261
# viacoin                 1259
# bitshares               1256
#                         ...
# amber                     66
# ...

# %%
currency_count = len(consolidated_coin_df["Currency"].unique())
currency_count
# Out:
# 200

# %%
lowest_open = consolidated_coin_df["Currency"].min()
largest_open = consolidated_coin_df["Currency"].min()
